# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

import json
import common

# %%
with open('../data/capacitors__ceramic_capacitors__page_15356-digikey.json', 'r') as outfile:
    data = json.load(outfile)

# %%
common.publish_data_test(data)

# %%
test ="""
{'resource': '/normalize', 'path': '/normalize', 'httpMethod': 'POST', 'headers': {'Accept': '*/*', 'CloudFront-Forwarded-Proto': 'https', 'CloudFront-Is-Desktop-Viewer': 'true', 'CloudFront-Is-Mobile-Viewer': 'false', 'CloudFront-Is-SmartTV-Viewer': 'false', 'CloudFront-Is-Tablet-Viewer': 'false', 'CloudFront-Viewer-Country': 'US', 'Content-Type': 'application/json', 'Host': 'bpezinqvm6.execute-api.eu-central-1.amazonaws.com', 'User-Agent': 'curl/7.55.1', 'Via': '1.1 a170a9e8f9393700a8de4715a0943846.cloudfront.net (CloudFront)', 'X-Amz-Cf-Id': 'YrzvbYJQkLGsybw5yEMg5Ql3jfquiIO5QifSKNFRyupbm_dKxJqNZA==', 'X-Amzn-Trace-Id': 'Root=1-5ad5003a-04bcb440d71400ac60cb6eb8', 'X-Forwarded-For': '73.167.113.2, 52.46.29.89', 'X-Forwarded-Port': '443', 'X-Forwarded-Proto': 'https'}, 'queryStringParameters': None, 'pathParameters': None, 'stageVariables': None, 'requestContext': {'resourceId': 'viag1k', 'resourcePath': '/normalize', 'httpMethod': 'POST', 'extendedRequestId': 'Fcz5GGAaliAFiBg=', 'requestTime': '16/Apr/2018:19:57:46 +0000', 'path': '/dev/normalize', 'accountId': '202439666482', 'protocol': 'HTTP/1.1', 'stage': 'dev', 'requestTimeEpoch': 1523908666209, 'requestId': '6eb33df0-41b0-11e8-8086-eb6e1e6f9fd2', 'identity': {'cognitoIdentityPoolId': None, 'accountId': None, 'cognitoIdentityId': None, 'caller': None, 'sourceIp': '73.167.113.2', 'accessKey': None, 'cognitoAuthenticationType': None, 'cognitoAuthenticationProvider': None, 'userArn': None, 'userAgent': 'curl/7.55.1', 'user': None}, 'apiId': 'bpezinqvm6'}, 'body': '{"id":"ee0f209f8df1cc0de1ed6aa63a930361","parsing_id":"0b263b1159e0d687f41bcda83b804039","ts":1518755830468,"source":"digikey","url":"https://www.digikey.com/products/en/capacitors/ceramic-capacitors/60/page/15356","url_next":"https://www.digikey.com/products/en/capacitors/ceramic-capacitors/60/page/15357","parts":[{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D120GXAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D120GXAAP/VJ0402D120GXAAP-ND/5099755"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D120GXAAP","mfr":"Vishay Vitramon","description":"CAP CER 12PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"12pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D120GXXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D120GXXAP/VJ0402D120GXXAP-ND/5099764"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D120GXXAP","mfr":"Vishay Vitramon","description":"CAP CER 12PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"12pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D130GLAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D130GLAAP/VJ0402D130GLAAP-ND/5099862"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D130GLAAP","mfr":"Vishay Vitramon","description":"CAP CER 13PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"13pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D130GLXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D130GLXAP/VJ0402D130GLXAP-ND/5099871"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D130GLXAP","mfr":"Vishay Vitramon","description":"CAP CER 13PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"13pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D130GXAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D130GXAAP/VJ0402D130GXAAP-ND/5099874"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D130GXAAP","mfr":"Vishay Vitramon","description":"CAP CER 13PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"13pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D130GXXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D130GXXAP/VJ0402D130GXXAP-ND/5099883"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D130GXXAP","mfr":"Vishay Vitramon","description":"CAP CER 13PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"13pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D150GLAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D150GLAAP/VJ0402D150GLAAP-ND/5099982"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D150GLAAP","mfr":"Vishay Vitramon","description":"CAP CER 15PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"15pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D150GLXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D150GLXAP/VJ0402D150GLXAP-ND/5099991"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D150GLXAP","mfr":"Vishay Vitramon","description":"CAP CER 15PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"15pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D150GXAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D150GXAAP/VJ0402D150GXAAP-ND/5099994"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D150GXAAP","mfr":"Vishay Vitramon","description":"CAP CER 15PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"15pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D150GXXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D150GXXAP/VJ0402D150GXXAP-ND/5100003"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D150GXXAP","mfr":"Vishay Vitramon","description":"CAP CER 15PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"15pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D180GLAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D180GLAAP/VJ0402D180GLAAP-ND/5100089"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D180GLAAP","mfr":"Vishay Vitramon","description":"CAP CER 18PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"18pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D180GLXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D180GLXAP/VJ0402D180GLXAP-ND/5100092"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D180GLXAP","mfr":"Vishay Vitramon","description":"CAP CER 18PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"18pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D180GXAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D180GXAAP/VJ0402D180GXAAP-ND/5100095"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D180GXAAP","mfr":"Vishay Vitramon","description":"CAP CER 18PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"18pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D180GXXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D180GXXAP/VJ0402D180GXXAP-ND/5100098"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D180GXXAP","mfr":"Vishay Vitramon","description":"CAP CER 18PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"18pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D200GLAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D200GLAAP/VJ0402D200GLAAP-ND/5100865"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D200GLAAP","mfr":"Vishay Vitramon","description":"CAP CER 20PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"20pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D200GLXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D200GLXAP/VJ0402D200GLXAP-ND/5100868"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D200GLXAP","mfr":"Vishay Vitramon","description":"CAP CER 20PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"20pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D200GXAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D200GXAAP/VJ0402D200GXAAP-ND/5100871"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D200GXAAP","mfr":"Vishay Vitramon","description":"CAP CER 20PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"20pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D200GXXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D200GXXAP/VJ0402D200GXXAP-ND/5100874"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D200GXXAP","mfr":"Vishay Vitramon","description":"CAP CER 20PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"20pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D220GLAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D220GLAAP/VJ0402D220GLAAP-ND/5100925"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D220GLAAP","mfr":"Vishay Vitramon","description":"CAP CER 22PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"22pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D220GLXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D220GLXAP/VJ0402D220GLXAP-ND/5100928"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D220GLXAP","mfr":"Vishay Vitramon","description":"CAP CER 22PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"22pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D220GXAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D220GXAAP/VJ0402D220GXAAP-ND/5100931"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D220GXAAP","mfr":"Vishay Vitramon","description":"CAP CER 22PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"22pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D220GXXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D220GXXAP/VJ0402D220GXXAP-ND/5100934"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D220GXXAP","mfr":"Vishay Vitramon","description":"CAP CER 22PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"22pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D240GLAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D240GLAAP/VJ0402D240GLAAP-ND/5100985"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D240GLAAP","mfr":"Vishay Vitramon","description":"CAP CER 24PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"24pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D240GLXAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D240GLXAP/VJ0402D240GLXAP-ND/5100988"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D240GLXAP","mfr":"Vishay Vitramon","description":"CAP CER 24PF 25V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"24pF","tolerance":"±2%","voltage_rated":"25V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"},{"categories":["Capacitors","Ceramic Capacitors"],"pricing":[{"quantity":1,"price":0.59746,"currency":"USD"}],"packaging":["Tape & Reel (TR)"],"sku":["VJ0402D240GXAAP-ND"],"links":{"datasheet":"http://www.vishay.com/docs/45071/vjhifreq.pdf","image":"https://media.digikey.com/Renders/Vishay%20Vitramon%20Renders/VJ%20SEries,%20HIFREQ%200402%2061mm_tmb.jpg","url":"https://www.digikey.com/product-detail/en/vishay-vitramon/VJ0402D240GXAAP/VJ0402D240GXAAP-ND/5100991"},"case":["0402 (1005 Metric)"],"mpn":"VJ0402D240GXAAP","mfr":"Vishay Vitramon","description":"CAP CER 24PF 50V C0G/NP0 0402","availability":0,"minimum_quantity":10000,"series":"VJ HIFREQ","lifecycle":"Active","capacitance":"24pF","tolerance":"±2%","voltage_rated":"50V","temperature_coefficient":"C0G, NP0","operating_temperature":"-55°C ~ 125°C","features":"High Q, Low Loss","applications":"RF, Microwave, High Frequency","mounting_type":"Surface Mount, MLCC","size_dimension":"0.040\\" L x 0.020\\" W (1.02mm x 0.51mm)","thickness_(max)":"0.024\\" (0.61mm)"}]}', 'isBase64Encoded': False}
"""

# %%
test  =eval(test)

# %%
body =test['body']

# %%
print(body)

# %%
len('')
